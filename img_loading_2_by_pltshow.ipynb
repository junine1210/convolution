# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
from skimage.exposure import rescale_intensity

# %%
img=cv2.imread('messi5.jpg')

# %%
plt.subplot(121)
plt.title('Original')
plt.xticks([])
plt.yticks([])
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))#bgr2rgb

plt.subplot(122)
plt.title('Averaging')
plt.xticks([])
plt.yticks([])
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))#bgr2rgb

plt.show()
